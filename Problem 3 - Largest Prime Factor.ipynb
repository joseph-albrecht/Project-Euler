# %% [markdown]
# # Problem 3 - Largest Prime Factor

# %% [markdown]
# The prime factors of 13195 are 5, 7, 13 and 29.
#
# What is the largest prime factor of the number 600851475143 ?

# %% [markdown]
# ## Search from half the number down

# %% [markdown]
# This is too slow.
# Hits maximum recursion depth with large numbers

# %%
import math
def largest_prime_factor1(number = 0):
    half_number = int(number/2)
    for potential_factor in reversed(range(half_number + 1)):
        if potential_factor <= 1:
            return 1
        elif number % potential_factor == 0:
            if largest_prime_factor1(potential_factor) == 1:
                return potential_factor

# %%
# %timeit largest_prime_factor1(3222)
# Out:
# 1000 loops, best of 3: 448 µs per loop

# %%
print(largest_prime_factor1(3222))
# Out:
# 179

# %% [markdown]
# ## Caching largest_factors

# %% [markdown]
# This is faster, but still too slow

# %%
def largest_prime_factor2(number = 0, numbers_to_largest_factor = {}):
    half_number = int(number/2)
    for potential_factor in reversed(range(half_number + 1)):
        if potential_factor <= 1:
            return 1
        elif number % potential_factor == 0:
            if potential_factor not in numbers_to_largest_factor:
                largest_factor = largest_prime_factor2(potential_factor, numbers_to_largest_factor)
                numbers_to_largest_factor[potential_factor] = largest_factor
                if largest_factor == 1:
                    return potential_factor
            elif numbers_to_largest_factor[potential_factor] == 1:
                return potential_factor

# %%
# %timeit largest_prime_factor2(3222)
# Out:
# The slowest run took 5.76 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 189 µs per loop

# %%
print(largest_prime_factor2(3222))
# Out:
# 179

# %% [markdown]
# ## Searching the space differently

# %%
def largest_prime_factor3(number = 0, numbers_to_largest_factor = {}):
    square_root = int(math.sqrt(number))
    range_one = range(1, square_root + 1)
    range_two = reversed(range(square_root + 1))
    ranges = [range_one, range_two]
    for index, r in enumerate(ranges):
        for potential_factor in r: 
            if index == 1 and potential_factor <= 1:
                return 1
            if number % potential_factor == 0:
                if index == 0:
                    potential_factor = number / potential_factor
                if potential_factor not in numbers_to_largest_factor:
                    numbers_to_largest_factor[potential_factor] = largest_prime_factor3(potential_factor, numbers_to_largest_factor)
                if numbers_to_largest_factor[potential_factor] == 1:
                    return potential_factor

# %%
# %timeit largest_prime_factor3(5)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-257-aa874815ff91> in <module>()
# ----> 1 get_ipython().magic('timeit largest_prime_factor3(5)')
#
# /Users/jalbrecht/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/jalbrecht/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /Users/jalbrecht/anaconda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/jalbrecht/anaconda/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#    1047             number = 1
#    1048             for _ in range(1, 10):
# -> 1049                 time_number = timer.timeit(number)
#    1050                 worst_tuning = max(worst_tuning, time_number / number)
#    1051                 if time_number >= 0.2:
#
# /Users/jalbrecht/anaconda/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-256-60c0c21e8394> in largest_prime_factor3(number, numbers_to_largest_factor)
#      12                     potential_factor = number / potential_factor
#      13                 if potential_factor not in numbers_to_largest_factor:
# ---> 14                     numbers_to_largest_factor[potential_factor] = largest_prime_factor3(potential_factor, numbers_to_largest_factor)
#      15                 if numbers_to_largest_factor[potential_factor] == 1:
#      16                     return potential_factor
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-256-60c0c21e8394> in largest_prime_factor3(number, numbers_to_largest_factor)
#      12                     potential_factor = number / potential_factor
#      13                 if potential_factor not in numbers_to_largest_factor:
# ---> 14                     numbers_to_largest_factor[potential_factor] = largest_prime_factor3(potential_factor, numbers_to_largest_factor)
#      15                 if numbers_to_largest_factor[potential_factor] == 1:
#      16                     return potential_factor
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
print(largest_prime_factor3(10))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-255-f18a9b039a5b> in <module>()
# ----> 1 print(largest_prime_factor3(10))
#
# <ipython-input-253-1658b0bec33b> in largest_prime_factor3(number, numbers_to_largest_factor)
#      12                     potential_factor = number / potential_factor
#      13                 if potential_factor not in numbers_to_largest_factor:
# ---> 14                     numbers_to_largest_factor[potential_factor] = largest_prime_factor3(potential_factor, numbers_to_largest_factor)
#      15                     print ("number: {} largest_factor: {}".format(potential_factor, numbers_to_largest_factor[potential_factor]))
#      16                 if numbers_to_largest_factor[potential_factor] == 1:
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-253-1658b0bec33b> in largest_prime_factor3(number, numbers_to_largest_factor)
#      12                     potential_factor = number / potential_factor
#      13                 if potential_factor not in numbers_to_largest_factor:
# ---> 14                     numbers_to_largest_factor[potential_factor] = largest_prime_factor3(potential_factor, numbers_to_largest_factor)
#      15                     print ("number: {} largest_factor: {}".format(potential_factor, numbers_to_largest_factor[potential_factor]))
#      16                 if numbers_to_largest_factor[potential_factor] == 1:
#
# RecursionError: maximum recursion depth exceeded in comparison
